# %%
library(SASxport)
library(dplyr)
library(IDPmisc)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
pdemo = read.xport('/Users/silviacatalina/Google Drive/BethelTech/DS0110-FinalProject/NHANES/Data/P_DEMO.XPT')
#pdemo %>% group_by(RIDAGEMN)%>% summarise(n=n())
head(pdemo)
# Out:
#   SEQN   SDDSRVYR RIDSTATR RIAGENDR RIDAGEYR RIDAGEMN RIDRETH1 RIDRETH3
# 1 109263 66       2        1         2       NA       5        6
# 2 109264 66       2        2        13       NA       1        1
# 3 109265 66       2        1         2       NA       3        3
# 4 109266 66       2        2        29       NA       5        6
# 5 109267 66       1        2        21       NA       2        2
# 6 109268 66       1        2        18       NA       3        3
#   RIDEXMON DMDBORN4 ⋯ FIAINTRP MIALANG MIAPROXY MIAINTRP AIALANGA WTINTPRP
# 1  2       1        ⋯ 2        NA      NA       NA       NA        7891.762
# 2  2       1        ⋯ 2         1       2        2        1       11689.747
# 3  2       1        ⋯ 2        NA      NA       NA       NA       16273.826
# 4  2       2        ⋯ 2         1       2        2        1        7825.646
# 5 NA       2        ⋯ 2        NA      NA       NA       NA       26379.992
# ...

# %%
str(pdemo)
# Out:
# 'data.frame':	15560 obs. of  29 variables:
#  $ SEQN    : 'labelled' int  109263 109264 109265 109266 109267 109268 109269 109270 109271 109272 ...
#   ..- attr(*, "label")= chr "Respondent sequence number"
#  $ SDDSRVYR: 'labelled' int  66 66 66 66 66 66 66 66 66 66 ...
#   ..- attr(*, "label")= chr "Data release cycle"
#  $ RIDSTATR: 'labelled' int  2 2 2 2 1 1 2 2 2 2 ...
#   ..- attr(*, "label")= chr "Interview/Examination status"
#  $ RIAGENDR: 'labelled' int  1 2 1 2 2 2 1 2 1 1 ...
#   ..- attr(*, "label")= chr "Gender"
#  $ RIDAGEYR: 'labelled' int  2 13 2 29 21 18 2 11 49 0 ...
#   ..- attr(*, "label")= chr "Age in years at screening"
#  $ RIDAGEMN: 'labelled' int  NA NA NA NA NA NA NA NA NA 3 ...
#   ..- attr(*, "label")= chr "Age in months at screening - 0 to 24 mos"
#  $ RIDRETH1: 'labelled' int  5 1 3 5 2 3 2 4 3 1 ...
#   ..- attr(*, "label")= chr "Race/Hispanic origin"
#  $ RIDRETH3: 'labelled' int  6 1 3 6 2 3 2 4 3 1 ...
# ...

# %%
label(pdemo)
# Out:
#                                       SEQN
#               "Respondent sequence number"
#                                   SDDSRVYR
#                       "Data release cycle"
#                                   RIDSTATR
#             "Interview/Examination status"
#                                   RIAGENDR
#                                   "Gender"
#                                   RIDAGEYR
#                "Age in years at screening"
#                                   RIDAGEMN
# "Age in months at screening - 0 to 24 mos"
#                                   RIDRETH1
#                     "Race/Hispanic origin"
#                                   RIDRETH3
#         "Race/Hispanic origin w/ NH Asian"
#                                   RIDEXMON
#                    "Six month time period"
#                                   DMDBORN4
#                         "Country of birth"
#                                   DMDYRUSZ
#                     "Length of time in US"
# ...

# %%
keep = c('SEQN','RIAGENDR','RIDAGEYR','RIDRETH3')
pdemo1 = pdemo[keep]
head(pdemo1)
# Out:
#   SEQN   RIAGENDR RIDAGEYR RIDRETH3
# 1 109263 1         2       6
# 2 109264 2        13       1
# 3 109265 1         2       3
# 4 109266 2        29       6
# 5 109267 2        21       2
# 6 109268 2        18       3

# %%
bp = read.xport('/Users/silviacatalina/Google Drive/BethelTech/DS0110-FinalProject/NHANES/Data/P_BPXO.XPT')
head(bp)
label(bp)
# Out:
#   SEQN   BPAOARM BPAOCSZ BPXOSY1 BPXODI1 BPXOSY2 BPXODI2 BPXOSY3 BPXODI3
# 1 109264 R       3       109     67      109     68      106     66
# 2 109266 R       4        99     56       99     55       99     52
# 3 109270 R       3       123     73      124     77      127     70
# 4 109271 R       4       102     65      108     68      111     68
# 5 109273 R       3       116     68      110     66      115     68
# 6 109274 NA      3       138     70      132     69      132     71
#   BPXOPLS1 BPXOPLS2 BPXOPLS3
# 1 94       95       91
# 2 68       66       66
# 3 95       98       93
# 4 73       71       70
# 5 71       70       70
# 6 NA       NA       NA
#                                    SEQN                                 BPAOARM
#            "Respondent sequence number"          "Arm selected - oscillometric"
#                                 BPAOCSZ                                 BPXOSY1
# ...

# %%
keep = c('SEQN', 'BPXOSY3', 'BPXODI3', 'BPXOPLS3')
bp1 = bp[keep]
head(bp1)
# Out:
#   SEQN   BPXOSY3 BPXODI3 BPXOPLS3
# 1 109264 106     66      91
# 2 109266  99     52      66
# 3 109270 127     70      93
# 4 109271 111     68      70
# 5 109273 115     68      70
# 6 109274 132     71      NA

# %%
dfmerged = merge(pdemo1,bp1)
head(dfmerged)
# Out:
#   SEQN   RIAGENDR RIDAGEYR RIDRETH3 BPXOSY3 BPXODI3 BPXOPLS3
# 1 109264 2        13       1        106     66      91
# 2 109266 2        29       6         99     52      66
# 3 109270 2        11       4        127     70      93
# 4 109271 1        49       3        111     68      70
# 5 109273 1        36       3        115     68      70
# 6 109274 1        68       7        132     71      NA

# %%
body = read.xport('/Users/silviacatalina/Google Drive/BethelTech/DS0110-FinalProject/NHANES/Data/P_BMX.XPT')
head(body)
label(body)
# Out:
#   SEQN   BMDSTATS BMXWT BMIWT BMXRECUM BMIRECUM BMXHEAD BMIHEAD BMXHT BMIHT ⋯
# 1 109263 4          NA  NA      NA     NA       NA      NA         NA NA    ⋯
# 2 109264 1        42.2  NA      NA     NA       NA      NA      154.7 NA    ⋯
# 3 109265 1        12.0  NA    91.6     NA       NA      NA       89.3 NA    ⋯
# 4 109266 1        97.1  NA      NA     NA       NA      NA      160.2 NA    ⋯
# 5 109269 3        13.6  NA    90.9     NA       NA      NA         NA  1    ⋯
# 6 109270 1        75.3  NA      NA     NA       NA      NA      156.0 NA    ⋯
#   BMXLEG BMILEG BMXARML BMIARML BMXARMC BMIARMC BMXWAIST BMIWAIST BMXHIP BMIHIP
# 1   NA   NA       NA    NA        NA    NA         NA    NA          NA  NA
# 2 36.3   NA     33.8    NA      22.7    NA       63.8    NA        85.0  NA
# 3   NA   NA     18.6    NA      14.8    NA       41.2    NA          NA  NA
# 4 40.8   NA     34.7    NA      35.8    NA      117.9    NA       126.1  NA
# ...

# %%
keep = c('SEQN','BMXWT','BMXHT','BMXBMI','BMXWAIST')
body1 = body[keep]
head(body1)
# Out:
#   SEQN   BMXWT BMXHT BMXBMI BMXWAIST
# 1 109263   NA     NA   NA      NA
# 2 109264 42.2  154.7 17.6    63.8
# 3 109265 12.0   89.3 15.0    41.2
# 4 109266 97.1  160.2 37.8   117.9
# 5 109269 13.6     NA   NA      NA
# 6 109270 75.3  156.0 30.9    91.4

# %%
dfmerged1 = merge(dfmerged, body1)
head(dfmerged1)
# Out:
#   SEQN   RIAGENDR RIDAGEYR RIDRETH3 BPXOSY3 BPXODI3 BPXOPLS3 BMXWT BMXHT BMXBMI
# 1 109264 2        13       1        106     66      91        42.2 154.7 17.6
# 2 109266 2        29       6         99     52      66        97.1 160.2 37.8
# 3 109270 2        11       4        127     70      93        75.3 156.0 30.9
# 4 109271 1        49       3        111     68      70        98.8 182.3 29.7
# 5 109273 1        36       3        115     68      70        74.3 184.2 21.9
# 6 109274 1        68       7        132     71      NA       103.7 185.3 30.2
#   BMXWAIST
# 1  63.8
# 2 117.9
# 3  91.4
# 4 120.4
# 5  86.8
# 6 109.6

# %%
bpchol = read.xport('/Users/silviacatalina/Google Drive/BethelTech/DS0110-FinalProject/NHANES/Data/P_BPQ.XPT')
head(bpchol)
label(bpchol)
# Out:
#   SEQN   BPQ020 BPQ030 BPD035 BPQ040A BPQ050A BPQ080 BPQ060 BPQ070 BPQ090D
# 1 109266 2      NA     NA     NA      NA      1      NA      1      2
# 2 109267 2      NA     NA     NA      NA      2       1      2      2
# 3 109268 2      NA     NA     NA      NA      2       9     NA     NA
# 4 109271 2      NA     NA     NA      NA      1      NA      1      1
# 5 109273 2      NA     NA     NA      NA      2       1      4      2
# 6 109274 1       1     54      1       1      1      NA      1      1
#   BPQ100D
# 1 NA
# 2 NA
# 3 NA
# 4  1
# 5 NA
# 6  1
#                                       SEQN
#               "Respondent sequence number"
#                                     BPQ020
#    "Ever told you had high blood pressure"
#                                     BPQ030
#  "Told had high blood pressure - 2+ times"
#                                     BPD035
#                "Age told had hypertension"
#                                    BPQ040A
# ...

# %%
keep = c('SEQN','BPQ020','BPQ080')
bpchol1 = bpchol[keep]
head(bpchol1)
# Out:
#   SEQN   BPQ020 BPQ080
# 1 109266 2      1
# 2 109267 2      2
# 3 109268 2      2
# 4 109271 2      1
# 5 109273 2      2
# 6 109274 1      1

# %%
dfmerged2 = merge(dfmerged1, bpchol1)
head(dfmerged2)
# Out:
#   SEQN   RIAGENDR RIDAGEYR RIDRETH3 BPXOSY3 BPXODI3 BPXOPLS3 BMXWT BMXHT BMXBMI
# 1 109266 2        29       6         99     52      66        97.1 160.2 37.8
# 2 109271 1        49       3        111     68      70        98.8 182.3 29.7
# 3 109273 1        36       3        115     68      70        74.3 184.2 21.9
# 4 109274 1        68       7        132     71      NA       103.7 185.3 30.2
# 5 109279 2        17       3        101     58      83        55.3 162.2 21.0
# 6 109282 1        76       3        140     70      55        83.3 177.1 26.6
#   BMXWAIST BPQ020 BPQ080
# 1 117.9    2      1
# 2 120.4    2      1
# 3  86.8    2      2
# 4 109.6    1      1
# 5  77.4    2      2
# 6    NA    1      1

# %%
dm = read.xport('/Users/silviacatalina/Google Drive/BethelTech/DS0110-FinalProject/NHANES/Data/P_DIQ.XPT')
head(dm)
label(dm)
# Out:
#   SEQN   DIQ010 DID040 DIQ160 DIQ180 DIQ050 DID060 DIQ060U DIQ070 DIQ230 ⋯
# 1 109263 2      NA     NA     NA     NA     NA     NA      NA     NA     ⋯
# 2 109264 2      NA      2      2     NA     NA     NA      NA     NA     ⋯
# 3 109265 2      NA     NA     NA     NA     NA     NA      NA     NA     ⋯
# 4 109266 2      NA      1      1     NA     NA     NA       2     NA     ⋯
# 5 109267 2      NA      2      2     NA     NA     NA      NA     NA     ⋯
# 6 109268 2      NA      2      2     NA     NA     NA      NA     NA     ⋯
#   DIQ300D DID310S DID310D DID320 DID330 DID341 DID350 DIQ350U DIQ360 DIQ080
# 1 NA      NA      NA      NA     NA     NA     NA     NA      NA     NA
# 2 NA      NA      NA      NA     NA     NA     NA     NA      NA     NA
# 3 NA      NA      NA      NA     NA     NA     NA     NA      NA     NA
# 4 NA      NA      NA      NA     NA     NA     NA     NA      NA     NA
# 5 NA      NA      NA      NA     NA     NA     NA     NA      NA     NA
# ...

# %%
keep = c('SEQN','DIQ010')
dm1 = dm[keep]
head(dm1)
# Out:
#   SEQN   DIQ010
# 1 109263 2
# 2 109264 2
# 3 109265 2
# 4 109266 2
# 5 109267 2
# 6 109268 2

# %%
dfmerged3 = merge(dfmerged2, dm1)
head(dfmerged3)
# Out:
#   SEQN   RIAGENDR RIDAGEYR RIDRETH3 BPXOSY3 BPXODI3 BPXOPLS3 BMXWT BMXHT BMXBMI
# 1 109266 2        29       6         99     52      66        97.1 160.2 37.8
# 2 109271 1        49       3        111     68      70        98.8 182.3 29.7
# 3 109273 1        36       3        115     68      70        74.3 184.2 21.9
# 4 109274 1        68       7        132     71      NA       103.7 185.3 30.2
# 5 109279 2        17       3        101     58      83        55.3 162.2 21.0
# 6 109282 1        76       3        140     70      55        83.3 177.1 26.6
#   BMXWAIST BPQ020 BPQ080 DIQ010
# 1 117.9    2      1      2
# 2 120.4    2      1      2
# 3  86.8    2      2      2
# 4 109.6    1      1      1
# 5  77.4    2      2      2
# 6    NA    1      1      2

# %%
fastbs = read.xport('/Users/silviacatalina/Google Drive/BethelTech/DS0110-FinalProject/NHANES/Data/P_GLU.XPT')
head(fastbs)
label(fastbs)
# Out:
#   SEQN   WTSAFPRP LBXGLU LBDGLUSI
# 1 109264 27533.17  97    5.38
# 2 109271 18100.97 103    5.72
# 3 109274 16281.76 154    8.55
# 4 109277 32230.05  92    5.11
# 5 109282 79007.10  95    5.27
# 6 109286     0.00  92    5.11
#                         SEQN                     WTSAFPRP
# "Respondent sequence number"   "Fasting Subsample Weight"
#                       LBXGLU                     LBDGLUSI
#    "Fasting Glucose (mg/dL)"   "Fasting Glucose (mmol/L)"

# %%
keep = c('SEQN','LBXGLU')
fastbs1 = fastbs[keep]
head(fastbs1)
# Out:
#   SEQN   LBXGLU
# 1 109264  97
# 2 109271 103
# 3 109274 154
# 4 109277  92
# 5 109282  95
# 6 109286  92

# %%
dfmerged4 = merge(dfmerged3, fastbs1)
head(dfmerged4)
# Out:
#   SEQN   RIAGENDR RIDAGEYR RIDRETH3 BPXOSY3 BPXODI3 BPXOPLS3 BMXWT BMXHT BMXBMI
# 1 109271 1        49       3        111     68      70        98.8 182.3 29.7
# 2 109274 1        68       7        132     71      NA       103.7 185.3 30.2
# 3 109282 1        76       3        140     70      55        83.3 177.1 26.6
# 4 109286 2        33       6         NA     NA      NA        72.6 158.4 28.9
# 5 109290 2        68       4        122     59      57        73.0 161.2 28.1
# 6 109292 1        58       2        133     97      92        86.0 167.8 30.5
#   BMXWAIST BPQ020 BPQ080 DIQ010 LBXGLU
# 1 120.4    2      1      2      103
# 2 109.6    1      1      1      154
# 3    NA    1      1      2       95
# 4    NA    2      2      2       92
# 5  92.0    1      2      1      106
# 6 108.3    1      1      1      181

# %%
str(dfmerged3)
# Out:
# 'data.frame':	9445 obs. of  14 variables:
#  $ SEQN    : 'labelled' int  109266 109271 109273 109274 109279 109282 109284 109285 109286 109290 ...
#   ..- attr(*, "label")= chr "Respondent sequence number"
#  $ RIAGENDR: 'labelled' int  2 1 1 1 2 1 2 1 2 2 ...
#   ..- attr(*, "label")= chr "Gender"
#  $ RIDAGEYR: 'labelled' int  29 49 36 68 17 76 44 16 33 68 ...
#   ..- attr(*, "label")= chr "Age in years at screening"
#  $ RIDRETH3: 'labelled' int  6 3 3 7 3 3 1 4 6 4 ...
#   ..- attr(*, "label")= chr "Race/Hispanic origin w/ NH Asian"
#  $ BPXOSY3 : 'labelled' int  99 111 115 132 101 140 NA 135 NA 122 ...
#   ..- attr(*, "label")= chr "Systolic - 3rd oscillometric reading"
#  $ BPXODI3 : 'labelled' int  52 68 68 71 58 70 NA 81 NA 59 ...
#   ..- attr(*, "label")= chr "Diastolic - 3rd oscillometric reading"
#  $ BPXOPLS3: 'labelled' int  66 70 70 NA 83 55 NA 61 NA 57 ...
#   ..- attr(*, "label")= chr "Pulse - 3rd oscillometric reading"
# ...

# %%
finaldf = NaRV.omit(dfmerged3)
str(finaldf)
# Out:
# 'data.frame':	7437 obs. of  14 variables:
#  $ SEQN    : 'labelled' int  109266 109271 109273 109279 109285 109290 109292 109293 109295 109297 ...
#   ..- attr(*, "label")= chr "Respondent sequence number"
#  $ RIAGENDR: 'labelled' int  2 1 1 2 1 2 1 1 2 2 ...
#   ..- attr(*, "label")= chr "Gender"
#  $ RIDAGEYR: 'labelled' int  29 49 36 17 16 68 58 44 54 30 ...
#   ..- attr(*, "label")= chr "Age in years at screening"
#  $ RIDRETH3: 'labelled' int  6 3 3 3 4 4 2 3 1 6 ...
#   ..- attr(*, "label")= chr "Race/Hispanic origin w/ NH Asian"
#  $ BPXOSY3 : 'labelled' int  99 111 115 101 135 122 133 130 158 102 ...
#   ..- attr(*, "label")= chr "Systolic - 3rd oscillometric reading"
#  $ BPXODI3 : 'labelled' int  52 68 68 58 81 59 97 84 92 68 ...
#   ..- attr(*, "label")= chr "Diastolic - 3rd oscillometric reading"
#  $ BPXOPLS3: 'labelled' int  66 70 70 83 61 57 92 64 89 80 ...
#   ..- attr(*, "label")= chr "Pulse - 3rd oscillometric reading"
# ...

# %%
names(finaldf)= c('id', 'gender', 'ageYr', 'ethnicity', 'bps', 'bpd', 'pulse', 'weight', 'height', 'bmi','waist', 'hx_hibp', 'hx_hichol', 'hx_dm')
head(finaldf)
# Out:
#    id     gender ageYr ethnicity bps bpd pulse weight height bmi  waist hx_hibp
# 1  109266 2      29    6          99 52  66     97.1  160.2  37.8 117.9 2
# 2  109271 1      49    3         111 68  70     98.8  182.3  29.7 120.4 2
# 3  109273 1      36    3         115 68  70     74.3  184.2  21.9  86.8 2
# 5  109279 2      17    3         101 58  83     55.3  162.2  21.0  77.4 2
# 8  109285 1      16    4         135 81  61    123.5  174.1  40.7 127.5 2
# 10 109290 2      68    4         122 59  57     73.0  161.2  28.1  92.0 1
#    hx_hichol hx_dm
# 1  1         2
# 2  1         2
# 3  2         2
# 5  2         2
# 8  2         2
# 10 2         1

# %%
options(repr.plot.width=20, repr.plot.height=20)

# %%
pairs(finaldf)
# Out:
# plot without title

# %%
label(finaldf)
# Out:
#                                         id
#               "Respondent sequence number"
#                                     gender
#                                   "Gender"
#                                      ageYr
#                "Age in years at screening"
#                                  ethnicity
#         "Race/Hispanic origin w/ NH Asian"
#                                        bps
#     "Systolic - 3rd oscillometric reading"
#                                        bpd
#    "Diastolic - 3rd oscillometric reading"
#                                      pulse
#        "Pulse - 3rd oscillometric reading"
#                                     weight
#                              "Weight (kg)"
#                                     height
#                     "Standing Height (cm)"
#                                        bmi
#                "Body Mass Index (kg/m**2)"
#                                      waist
#                 "Waist Circumference (cm)"
# ...
